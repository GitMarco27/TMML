# %% [markdown]
# <a href="https://colab.research.google.com/github/GitMarco27/TMML/blob/main/000_channel_teaser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3 Minutes Machine Learning
# ## Episode 0: Channel Teaser
#
# #### Marco Sanguineti, 2021
# ---

# %% [markdown]
# Welcome to 3 minutes Machine Learning!

# %%
import matplotlib.pyplot as plt

# %%
# Let's import this video thumbnail!
# Hi, and welcome!!
myThumb = plt.imread('/tmp/yt_thumb_1.png')
fig, ax = plt.subplots(figsize=(15, 10))
plt.axis('off')
ax.imshow(myThumb)
plt.show()

# %% [markdown]
# #### Video Topics
# > 1. View the cover: done! ✅
# > 2. Channel content
# > 3. Format
# > 4. See you on next video!

# %%
# Let's read a simple .txt file
with open('/tmp/intro.txt', 'r') as file:
  txt = file.read()
print(txt)
# Out:
# Welcome to 3 minutes machine learning!
# This channel will present a series of tutorials, case studies,
# applications and trivia related to the world of machine learning and data analysis.
# We will talk about Tensorflow, Pytorch, sklearn and various tools
# that can be useful to quickly approach this interesting world.

# %% [markdown]
# ### Videos format
#
#
#
# > 1. **3 minutes** video
# > 2. Projects and tutorials developed in google **Colab** and **Python code**
# > 3. Projects commented by me or accompanied by lo-fi music
# > 4. **Video series** for more complex and interesting topics

# %% [markdown]
# ### Greetings
# ---

# %%
from art import tprint, aprint
tprint('See you on next videos!')
# Out:
#  ____                                                                        _            _      _                    _
# / ___|   ___   ___   _   _   ___   _   _    ___   _ __    _ __    ___ __  __| |_  __   __(_)  __| |  ___   ___   ___ | |
# \___ \  / _ \ / _ \ | | | | / _ \ | | | |  / _ \ | '_ \  | '_ \  / _ \\ \/ /| __| \ \ / /| | / _` | / _ \ / _ \ / __|| |
#  ___) ||  __/|  __/ | |_| || (_) || |_| | | (_) || | | | | | | ||  __/ >  < | |_   \ V / | || (_| ||  __/| (_) |\__ \|_|
# |____/  \___| \___|  \__, | \___/  \__,_|  \___/ |_| |_| |_| |_| \___|/_/\_\ \__|   \_/  |_| \__,_| \___| \___/ |___/(_)
#                      |___/

# %%
def subscribe():
  """
  Attractive subscription form
  """
  aprint("giveme", number=5)
  print(f'\n\tLike and subscribe to support this work!\n')
  aprint("giveme", number=5)

# %%
# Let's add some final click-bait content
subscribe()
# Out:
# ༼ つ ◕_◕ ༽つ ༼ つ ◕_◕ ༽つ ༼ つ ◕_◕ ༽つ ༼ つ ◕_◕ ༽つ ༼ つ ◕_◕ ༽つ
#
# 	Like and subscribe to support this work!
#
# ༼ つ ◕_◕ ༽つ ༼ つ ◕_◕ ༽つ ༼ つ ◕_◕ ༽つ ༼ つ ◕_◕ ༽つ ༼ つ ◕_◕ ༽つ
